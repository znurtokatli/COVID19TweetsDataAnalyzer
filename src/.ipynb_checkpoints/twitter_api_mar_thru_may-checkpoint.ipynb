# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import requests
import json
from api_keys import g_key
import gmaps
import glob

# %%
def raw_data_by_month(month):
    files = [i for i in glob.glob('../resources/twitterapi/{}*.{}'.format(month,'csv'))] 

    raw_df = pd.concat([pd.read_csv(f, parse_dates=['created_at']) for f in files ])  
    
    return raw_df

# %%
march_df = raw_data_by_month('03')
march_df = march_df.sort_values(by="created_at")
march_df
# Out:
# /Users/jameswhite/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       coordinates                created_at                          hashtags  \
# 72151         NaN 2020-03-01 12:00:00+00:00                               NaN
# 72297         NaN 2020-03-01 12:00:00+00:00  Coronavirus pmi OPEC marketsnews
# 72193         NaN 2020-03-01 12:00:00+00:00                               NaN
# 72295         NaN 2020-03-01 12:00:00+00:00                               NaN
# 72250         NaN 2020-03-01 12:00:00+00:00                       coronavirus
# ...           ...                       ...                               ...
# 39023         NaN 2020-03-25 12:56:29+00:00                               NaN
# 39011         NaN 2020-03-25 12:56:29+00:00                           COVID19
# 39026         NaN 2020-03-25 12:56:30+00:00                               NaN
# 39003         NaN 2020-03-25 12:56:30+00:00                               NaN
# 39025         NaN 2020-03-25 12:56:30+00:00                               NaN
#
#                                                    media  \
# 72151  https://twitter.com/goss_ie/status/12340859813...
# 72297  https://twitter.com/Marketsdotcom/status/12340...
# 72193                                                NaN
# 72295                                                NaN
# 72250  https://twitter.com/ArabNewsjp/status/12340859...
# ...                                                  ...
# 39023                                                NaN
# 39011  https://twitter.com/ANI/status/124276819432812...
# 39026                                                NaN
# 39003                                                NaN
# 39025                                                NaN
#
#                                                     urls  favorite_count  \
# 72151                             https://bit.ly/2TatY7m               0
# 72297  http://live-trader.markets.com/trading-platfor...               0
# 72193  https://www.independent.co.uk/independentpremi...               0
# 72295                                                NaN               0
# 72250                            https://arab.news/7nvsk               1
# ...                                                  ...             ...
# 39023                                                NaN               0
# 39011                                                NaN               0
# 39026                                                NaN               0
# 39003                                                NaN               0
# 39025                                                NaN               0
#
#                         id in_reply_to_screen_name  in_reply_to_status_id  \
# 72151  1234085981365600259                     NaN                    NaN
# 72297  1234085980602277888                     NaN                    NaN
# 72193  1234085981113982976                     NaN                    NaN
# 72295  1234085978622582789                     NaN                    NaN
# 72250  1234085979201396736                     NaN                    NaN
# ...                    ...                     ...                    ...
# 39023  1242797504199974912                     NaN                    NaN
# 39011  1242797504304836611                     NaN                    NaN
# 39026  1242797508134187011                     NaN                    NaN
# 39003  1242797508134203392                     NaN                    NaN
# 39025  1242797508218228741                     NaN                    NaN
#
#        in_reply_to_user_id  ... user_followers_count user_friends_count  \
# 72151                  NaN  ...                15301               2484
# 72297                  NaN  ...                 7223                204
# 72193                  NaN  ...                  412               3420
# 72295                  NaN  ...                17127              10114
# 72250                  NaN  ...                13408                 60
# ...                    ...  ...                  ...                ...
# 39023                  NaN  ...                  957               1698
# 39011                  NaN  ...                   34                555
# 39026                  NaN  ...                  595                420
# 39003                  NaN  ...                 1789                724
# 39025                  NaN  ...                 1511                211
#
#       user_listed_count        user_location          user_name  \
# 72151               120              Ireland            Goss.ie
# 72297                35                  NaN            Markets
# 72193                 0              Ecuador                 DH
# 72295               131        United States          Gbemisola
# 72250               168                  NaN    Arab News Japan
# ...                 ...                  ...                ...
# 39023               103                  NaN            BarbVee
# 39011                 0        Odisha ,india      Dank Bishal🧐😎
# 39026                 5  Bandung, Jawa Barat        munchmunch🍭
# 39003                40        CKA Vancouver      Carrie Bercic
# 39025                 5             Colombia  Estrategia Unidos
#
#       user_screen_name.1 user_statuses_count user_time_zone  \
# 72151            goss_ie              108545            NaN
# 72297      Marketsdotcom                2665            NaN
# 72193            dfh1977               15130            NaN
# 72295            gbemy01              421374            NaN
# 72250         ArabNewsjp               21764            NaN
# ...                  ...                 ...            ...
# 39023            barbvee              177133            NaN
# 39011    prasenjitmohap1               12629            NaN
# 39026       munnycahyani               52283            NaN
# 39003       CarrieBercic               25685            NaN
# 39025         Unidos_Col                6459            NaN
#
#                                                user_urls user_verified
# 72151                                 http://www.goss.ie          True
# 72297  https://live-trader.markets.com/trading-platfo...         False
# 72193                                                NaN         False
# 72295                             http://www.gbemy01.com         False
# 72250                                 http://arabnews.jp          True
# ...                                                  ...           ...
# 39023                                                NaN         False
# 39011                                                NaN         False
# 39026                                                NaN         False
# 39003                                                NaN         False
# 39025                                                NaN         False
#
# [232217 rows x 34 columns]

# %%
april_df = raw_data_by_month('04')
april_df = april_df.sort_values(by="created_at")
april_df
# Out:
#       coordinates                created_at  \
# 36064         NaN 2020-04-01 12:00:00+00:00
# 36110         NaN 2020-04-01 12:00:00+00:00
# 36112         NaN 2020-04-01 12:00:00+00:00
# 36122         NaN 2020-04-01 12:00:01+00:00
# 36095         NaN 2020-04-01 12:00:03+00:00
# ...           ...                       ...
# 37540         NaN 2020-04-25 12:55:34+00:00
# 37549         NaN 2020-04-25 12:55:34+00:00
# 37550         NaN 2020-04-25 12:55:34+00:00
# 37551         NaN 2020-04-25 12:55:34+00:00
# 37557         NaN 2020-04-25 12:55:34+00:00
#
#                                 hashtags  \
# 36064                                NaN
# 36110  Millionen Sars flucht fluchtgrund
# 36112                                NaN
# 36122                             Corona
# 36095                             Corona
# ...                                  ...
# 37540                                NaN
# 37549                                NaN
# 37550                            covid19
# 37551                                NaN
# 37557                                NaN
#
#                                                    media  \
# 36064                                                NaN
# 36110  https://twitter.com/earthlinkev/status/1245320...
# 36112                                                NaN
# 36122                                                NaN
# 36095                                                NaN
# ...                                                  ...
# 37540                                                NaN
# 37549                                                NaN
# 37550                                                NaN
# 37551                                                NaN
# 37557  https://twitter.com/RAMESHG43562581/status/125...
#
#                                                     urls  favorite_count  \
# 36064                                                NaN               0
# 36110  http://www.fluchtgrund.de/2020/04/globale-vera...               0
# 36112  https://www.tagesanzeiger.ch/eu-staaten-forder...               7
# 36122                                                NaN               0
# 36095                                                NaN               0
# ...                                                  ...             ...
# 37540                                                NaN               0
# 37549                                                NaN               0
# 37550                                                NaN               0
# 37551  https://www.matichon.co.th/covid19/thai-covid1...               0
# 37557                                                NaN               0
#
#                         id in_reply_to_screen_name  in_reply_to_status_id  \
# 36064  1245320005165686792                     NaN                    NaN
# 36110  1245320002980347905                     NaN                    NaN
# 36112  1245320004616273921                     NaN                    NaN
# 36122  1245320006105280519                     NaN                    NaN
# 36095  1245320015928320000                     NaN                    NaN
# ...                    ...                     ...                    ...
# 37540  1254031297086816256                     NaN                    NaN
# 37549  1254031297116332032            zhangxin9261           1.253943e+18
# 37550  1254031297296715778                     NaN                    NaN
# 37551  1254031297191620608                     NaN                    NaN
# 37557  1254031296449245184            narendramodi                    NaN
#
#        in_reply_to_user_id  ... user_followers_count user_friends_count  \
# 36064                  NaN  ...                  514                720
# 36110                  NaN  ...                  455                368
# 36112                  NaN  ...               190621               1226
# 36122                  NaN  ...                  101                340
# 36095                  NaN  ...                   30                173
# ...                    ...  ...                  ...                ...
# 37540                  NaN  ...                   78                134
# 37549         9.783071e+17  ...                  569               1863
# 37550                  NaN  ...                  381                180
# 37551                  NaN  ...                  220                578
# 37557         1.883978e+07  ...                    0                  6
#
#       user_listed_count              user_location  \
# 36064                 7                        NaN
# 36110                50          München - Germany
# 36112              1109                     Zürich
# 36122                 4                        NaN
# 36095                 1
# ...                 ...                        ...
# 37540                 0                     Bekasi
# 37549                 0                        NaN
# 37550                 1      Furci Siculo, Sicilia
# 37551                 7  ชิปที่ใจใช่โมเม้น ใจล้วนๆ
# 37557                 0                        NaN
#
#                         user_name user_screen_name.1 user_statuses_count  \
# 36064                  Tonie Rosa      ClaireLaaffat               34420
# 36110              earthlink e.V.        earthlinkev               10886
# 36112               tagesanzeiger      tagesanzeiger               96111
# 36122                anonymmuslim       anonymmuslim                3677
# 36095                        powl           powlomat                 798
# ...                           ...                ...                 ...
# 37540  INDONESIA MAJU (iyong pnj)    iyongpananjung1                2553
# 37549                    Ace12551           Ace12551                7494
# 37550                Fabio Raciti       Fabioraciti1               42452
# 37551     แผงฟันหน้าของจ่าสิก |||      NineZenith_JP              406412
# 37557                    RAMESH G    RAMESHG43562581                  23
#
#       user_time_zone                user_urls user_verified
# 36064            NaN                      NaN         False
# 36110            NaN  http://www.earthlink.de         False
# 36112            NaN  http://tagesanzeiger.ch          True
# 36122            NaN                      NaN         False
# 36095            NaN                      NaN         False
# ...              ...                      ...           ...
# 37540            NaN                      NaN         False
# 37549            NaN                      NaN         False
# 37550            NaN                      NaN         False
# 37551            NaN                      NaN         False
# 37557            NaN                      NaN         False
#
# [223026 rows x 34 columns]

# %%
may_df = raw_data_by_month('05')
may_df = may_df.sort_values(by="created_at")
may_df
# Out:
# /Users/jameswhite/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3343: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       coordinates                created_at  \
# 63            NaN 2020-05-01 12:07:06+00:00
# 53            NaN 2020-05-01 12:07:06+00:00
# 52            NaN 2020-05-01 12:07:06+00:00
# 51            NaN 2020-05-01 12:07:06+00:00
# 50            NaN 2020-05-01 12:07:06+00:00
# ...           ...                       ...
# 37960         NaN 2020-05-25 12:59:59+00:00
# 37961         NaN 2020-05-25 12:59:59+00:00
# 37962         NaN 2020-05-25 12:59:59+00:00
# 37964         NaN 2020-05-25 12:59:59+00:00
# 37990         NaN 2020-05-25 12:59:59+00:00
#
#                                          hashtags  \
# 63     covid19 covid19PT coronavirus portugal dgs
# 53                                            NaN
# 52                                        Covid19
# 51                                            NaN
# 50                              COVID19 nutrition
# ...                                           ...
# 37960                                         NaN
# 37961                                         NaN
# 37962                                         NaN
# 37964                                         NaN
# 37990                                         NaN
#
#                                                    media  \
# 63     https://twitter.com/tvi24pt/status/12561934247...
# 53                                                   NaN
# 52                                                   NaN
# 51                                                   NaN
# 50                                                   NaN
# ...                                                  ...
# 37960                                                NaN
# 37961                                                NaN
# 37962                                                NaN
# 37964                                                NaN
# 37990                                                NaN
#
#                                                     urls  favorite_count  \
# 63                                                   NaN               2
# 53                                                   NaN               0
# 52                                                   NaN               0
# 51                                                   NaN               0
# 50                                                   NaN               0
# ...                                                  ...             ...
# 37960                                                NaN               0
# 37961                                                NaN               0
# 37962                                                NaN               0
# 37964  https://conexaopolitica.com.br/brasil/covid-19...               0
# 37990                                                NaN               0
#
#                         id in_reply_to_screen_name  in_reply_to_status_id  \
# 63     1256193424736256001                     NaN                    NaN
# 53     1256193427252711426                     NaN                    NaN
# 52     1256193427466711040                     NaN                    NaN
# 51     1256193427651342336                     NaN                    NaN
# 50     1256193427387056128                     NaN                    NaN
# ...                    ...                     ...                    ...
# 37960  1264904042100162560                     NaN                    NaN
# 37961  1264904044914642949                     NaN                    NaN
# 37962  1264904045342253057                     NaN                    NaN
# 37964  1264904042251259905                     NaN                    NaN
# 37990  1264904045723914240                     NaN                    NaN
#
#        in_reply_to_user_id  ... user_followers_count user_friends_count  \
# 63                     NaN  ...               267915                371
# 53                     NaN  ...                 1549               2425
# 52                     NaN  ...                  950               4938
# 51                     NaN  ...                  905                759
# 50                     NaN  ...                  924               1154
# ...                    ...  ...                  ...                ...
# 37960                  NaN  ...                   19                 24
# 37961                  NaN  ...                   79                672
# 37962                  NaN  ...                  787                925
# 37964                  NaN  ...                  164                 40
# 37990                  NaN  ...                   43                212
#
#       user_listed_count     user_location  \
# 63                  969          Portugal
# 53                   51               NaN
# 52                    6  Xalisco, Nayarit
# 51                   11    Washington, DC
# 50                    1               NaN
# ...                 ...               ...
# 37960                 0  Toronto, Ontario
# 37961                 4               NaN
# 37962                23       Los Angeles
# 37964                 1               NaN
# 37990                12               NaN
#
#                                     user_name user_screen_name.1  \
# 63                                      tvi24            tvi24pt
# 53                                      れもんあじ         lemontaste
# 52                 Pedro Arturo Rico Susarrey       ricosusarrey
# 51     Partnership for the Future of Learning    future4learning
# 50                     AdejokeTheNutritionist    adejoke_adewusi
# ...                                       ...                ...
# 37960                                  chad !           msnsmms6
# 37961                                 Awesome    Deborah23670479
# 37962                             CanDoAnHour      TheSickness85
# 37964                                 AlexTuy            alextuy
# 37990                             Desiography        desiography
#
#       user_statuses_count user_time_zone                         user_urls  \
# 63                 333387            NaN           http://www.tvi24.iol.pt
# 53                  29131            NaN                               NaN
# 52                  67255            NaN              http://www.mulza.com
# 51                   1772            NaN     https://futureforlearning.org
# 50                  10972            NaN                               NaN
# ...                   ...            ...                               ...
# 37960                4229            NaN                               NaN
# 37961                4503            NaN                               NaN
# 37962              193413            NaN  http://statelyxanadu.tumblr.com/
# 37964               47367            NaN                               NaN
# 37990                5279            NaN    http://desiography.tumblr.com/
#
#       user_verified
# 63             True
# 53            False
# 52            False
# 51            False
# 50            False
# ...             ...
# 37960         False
# 37961         False
# 37962         False
# 37964         False
# 37990         False
#
# [218538 rows x 34 columns]

# %%
def filter_data(raw_df):
    filtered_data = raw_df[['id', 'created_at', 'place', 'favorite_count','retweet_count']]
    filtered_data = filtered_data[raw_df['place'].notna()]
    filtered_data = filtered_data.reset_index(drop=True)
    filtered_data.rename(columns={'created_at':'Date', 'id':'Tweet ID', 'place': 'Place', 'favorite_count':'Favorite Count','retweet_count':'Retweet Count'}, inplace=True)
    filtered_data['Date'] = filtered_data['Date'].dt.strftime('%Y-%m-%d')
    filtered_data["Lat"] = ""
    filtered_data["Lng"] = ""
    filtered_data["Country"] = ""
    return filtered_data

# %%
march_filter = filter_data(march_df)
march_filter
# Out:
#                  Tweet ID        Date  \
# 0     1234086018376241152  2020-03-01
# 1     1234086036973740032  2020-03-01
# 2     1234086156901453825  2020-03-01
# 3     1234086179886202881  2020-03-01
# 4     1234086214996762624  2020-03-01
# ...                   ...         ...
# 2088  1242797462441558017  2020-03-25
# 2089  1242797466354933764  2020-03-25
# 2090  1242797490694283269  2020-03-25
# 2091  1242797495408824322  2020-03-25
# 2092  1242797499791835143  2020-03-25
#
#                                              Place  Favorite Count  \
# 0     Makkah Al Mukarrama, Kingdom of Saudi Arabia               1
# 1                                 Bristol, England               0
# 2                                 Walsall, England               0
# 3                                 Bristol, England               0
# 4            Central & Western District, Hong Kong               5
# ...                                            ...             ...
# 2088                          Dublin City, Ireland               0
# 2089                                    Tupelo, MS              46
# 2090                            Ungaran, Indonesia               0
# 2091                                   Kendall, FL               1
# 2092                        Bogotá, D.C., Colombia               1
#
#       Retweet Count Lat Lng Country
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ...             ...  ..  ..     ...
# 2088              0
# 2089              4
# 2090              0
# 2091              0
# 2092              0
#
# [2093 rows x 8 columns]

# %%
april_filter = filter_data(april_df)
april_filter
# Out:
#                  Tweet ID        Date                             Place  \
# 0     1245320603843858433  2020-04-01                  Hamburg, Germany
# 1     1245320869930586112  2020-04-01                    Cannes, France
# 2     1245321182062264322  2020-04-01  Zell am Harmersbach, Deutschland
# 3     1245321288425582593  2020-04-01            Prague, Czech Republic
# 4     1245322458921676801  2020-04-01                 Crediton, England
# ...                   ...         ...                               ...
# 2506  1254031217491673088  2020-04-25                    Lekki, Nigeria
# 2507  1254031221140721664  2020-04-25               Camden Town, London
# 2508  1254031242565242880  2020-04-25                   Guelph, Ontario
# 2509  1254031272558694405  2020-04-25                  Tallinn, Estonia
# 2510  1254031280980717568  2020-04-25                     Santa Ana, CA
#
#       Favorite Count  Retweet Count Lat Lng Country
# 0                  0              0
# 1                  0              0
# 2                  0              0
# 3                  1              0
# 4                  0              0
# ...              ...            ...  ..  ..     ...
# 2506               2              1
# 2507               1              0
# 2508               4              0
# 2509               0              1
# 2510               0              0
#
# [2511 rows x 8 columns]

# %%
may_filter = filter_data(may_df)
may_filter
# Out:
#                  Tweet ID        Date  \
# 0     1256193425415852032  2020-05-01
# 1     1256193436442476547  2020-05-01
# 2     1256193465077108737  2020-05-01
# 3     1256193469384712192  2020-05-01
# 4     1256193503115313152  2020-05-01
# ...                   ...         ...
# 2212  1264903991617617923  2020-05-25
# 2213  1264904010894413824  2020-05-25
# 2214  1264904037045956609  2020-05-25
# 2215  1264904045250121854  2020-05-25
# 2216  1264904044205805569  2020-05-25
#
#                                                   Place  Favorite Count  \
# 0                                    Kensington, London               4
# 1                                          Kantō, Chiba               0
# 2                                      Banbury, England               1
# 3                                  Lakeland Heights, TX               0
# 4                                         Shimla, India               3
# ...                                                 ...             ...
# 2212                               King's Lynn, England               1
# 2213                                    Dindigul, India               0
# 2214                             Ilagan, Cagayan Valley               0
# 2215                                   Rayachoti, India               1
# 2216  Robinson Memorial Methodist Marathi Central Ch...               3
#
#       Retweet Count Lat Lng Country
# 0                10
# 1                 0
# 2                 0
# 3                 0
# 4                 3
# ...             ...  ..  ..     ...
# 2212              0
# 2213              0
# 2214              0
# 2215              0
# 2216              0
#
# [2217 rows x 8 columns]

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": g_key}
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
# Loop through the cities_pd and run a lat/long search for each city
def append_geocode_country(geocode_df):
    for index, row in geocode_df.iterrows():
        address = row['Place']

        # update address key value
        params['address'] = f"{address}"

        # make request
#         cities = requests.get(base_url, params=params)
#         cities = cities.json()
        resp_data = requests.get(base_url, params=params).json()
       
    
        try: 
            geocode_df[index, "Lat"] = resp_data["results"][0]["geometry"]["location"]["lat"]
            geocode_df.loc[index, "Lng"] = resp_data["results"][0]["geometry"]["location"]["lng"]
        except:
           pass
        try:
            address_components = resp_data['results'][0]['address_components']
            for i in range(0, len(address_components)):
                if (address_components[i]['types'][0]) == "country":
                    geocode_df.loc[index, 'Country'] = address_components[i]['short_name']
        except:
            pass    
    geocode_df['Covid Cases'] = ""
    geocode_df = geocode_df.dropna()
    return geocode_df

# %%
march_data = append_geocode_country(march_filter)
march_data
# Out:
#                  Tweet ID        Date  \
# 0     1234086018376241152  2020-03-01
# 1     1234086036973740032  2020-03-01
# 2     1234086156901453825  2020-03-01
# 3     1234086179886202881  2020-03-01
# 4     1234086214996762624  2020-03-01
# ...                   ...         ...
# 2088  1242797462441558017  2020-03-25
# 2089  1242797466354933764  2020-03-25
# 2090  1242797490694283269  2020-03-25
# 2091  1242797495408824322  2020-03-25
# 2092  1242797499791835143  2020-03-25
#
#                                              Place  Favorite Count  \
# 0     Makkah Al Mukarrama, Kingdom of Saudi Arabia               1
# 1                                 Bristol, England               0
# 2                                 Walsall, England               0
# 3                                 Bristol, England               0
# 4            Central & Western District, Hong Kong               5
# ...                                            ...             ...
# 2088                          Dublin City, Ireland               0
# 2089                                    Tupelo, MS              46
# 2090                            Ungaran, Indonesia               0
# 2091                                   Kendall, FL               1
# 2092                        Bogotá, D.C., Colombia               1
#
#       Retweet Count  Lat         Lng Country   (0, Lat)   (1, Lat)  ...  \
# 0               0.0  NaN   43.356548      SA  23.274118  51.454513  ...
# 1               0.0  NaN   -2.587910      GB  23.274118  51.454513  ...
# 2               0.0  NaN   -1.982919      GB  23.274118  51.454513  ...
# 3               0.0  NaN   -2.587910      GB  23.274118  51.454513  ...
# 4               1.0  NaN  114.149881      HK  23.274118  51.454513  ...
# ...             ...  ...         ...     ...        ...        ...  ...
# 2088            0.0  NaN   -6.260310      IE  23.274118  51.454513  ...
# 2089            4.0  NaN  -88.703386      US  23.274118  51.454513  ...
# 2090            0.0  NaN  110.409877      ID  23.274118  51.454513  ...
# 2091            0.0  NaN  -80.357827      US  23.274118  51.454513  ...
# 2092            0.0  NaN  -74.072092      CO  23.274118  51.454513  ...
#
#       (2084, Lat)  (2085, Lat)  (2086, Lat)  (2087, Lat)  (2088, Lat)  \
# 0      -22.885927     51.92442    28.065297    -1.292066    53.349805
# 1      -22.885927     51.92442    28.065297    -1.292066    53.349805
# 2      -22.885927     51.92442    28.065297    -1.292066    53.349805
# 3      -22.885927     51.92442    28.065297    -1.292066    53.349805
# 4      -22.885927     51.92442    28.065297    -1.292066    53.349805
# ...           ...          ...          ...          ...          ...
# 2088   -22.885927     51.92442    28.065297    -1.292066    53.349805
# 2089   -22.885927     51.92442    28.065297    -1.292066    53.349805
# 2090   -22.885927     51.92442    28.065297    -1.292066    53.349805
# 2091   -22.885927     51.92442    28.065297    -1.292066    53.349805
# 2092   -22.885927     51.92442    28.065297    -1.292066    53.349805
#
#       (2089, Lat)  (2090, Lat)  (2091, Lat)  (2092, Lat)  Covid Cases
# 0       34.257607    -7.136431    25.666034     4.710989
# 1       34.257607    -7.136431    25.666034     4.710989
# 2       34.257607    -7.136431    25.666034     4.710989
# 3       34.257607    -7.136431    25.666034     4.710989
# 4       34.257607    -7.136431    25.666034     4.710989
# ...           ...          ...          ...          ...          ...
# 2088    34.257607    -7.136431    25.666034     4.710989
# 2089    34.257607    -7.136431    25.666034     4.710989
# 2090    34.257607    -7.136431    25.666034     4.710989
# 2091    34.257607    -7.136431    25.666034     4.710989
# 2092    34.257607    -7.136431    25.666034     4.710989
#
# [2093 rows x 2095 columns]

# %%
april_data = append_geocode_country(april_filter)
april_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-915b2a2b2875> in <module>
# ----> 1 april_data = append_geocode_country(april_filter)
#       2 april_data
#
# <ipython-input-11-62eec8395083> in append_geocode_country(geocode_df)
#      10 #         cities = requests.get(base_url, params=params)
#      11 #         cities = cities.json()
# ---> 12         resp_data = requests.get(base_url, params=params).json()
#      13
#      14
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
may_data = append_geocode_country(may_filter)
may_data

# %%
# map func
info_box_template = ""
def draw_map(month_df):
    month_df['Lat'] = pd.to_numeric(month_df['Lat'])
    month_df['Lng'] = pd.to_numeric(month_df['Lng'])
    month_df['Retweet Count'] = month_df['Retweet Count'].astype(float)
    month_df['Lat'] = pd.to_numeric(month_df['Lat'])
    month_df['Lng'] = pd.to_numeric(month_df['Lng'])
    month_df = month_df[month_df['Lat'].notna()]
    month_df['Retweet Count'] = month_df['Retweet Count'].astype(float)
    month_df['Favorite Count'] = month_df['Favorite Count'].astype(float)
    loc_df = month_df[["Lat", "Lng"]]
    
    gmaps.configure(api_key = g_key)
    map_figure = gmaps.figure()

    layer = gmaps.heatmap_layer(loc_df, weights = month_df['Favorite Count'], max_intensity=100, dissipating = False, point_radius = 0.5, opacity = 0.3)
    

    fig = gmaps.figure()
    markers = gmaps.marker_layer(loc_df)
    fig.add_layer(markers)
    fig
    
    
    return map_figure

# %%
draw_map(march_data)

# %%
draw_map(april_data)

# %%
draw_map(march_data)
