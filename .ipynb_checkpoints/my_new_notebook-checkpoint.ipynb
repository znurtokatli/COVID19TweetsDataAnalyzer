# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
file1 = 'twitterapi/030120.csv'
file2 = 'twitterapi/031520.csv'
file3 = 'twitterapi/040120.csv'
file4 = 'twitterapi/041520.csv'
file5 = 'twitterapi/050120.csv'
file6 = 'twitterapi/051520.csv'

# %%
twitter_mar_01 = pd.read_csv(file1)
twitter_mar_15 = pd.read_csv(file2)
twitter_apr_01 = pd.read_csv(file3)
twitter_apr_15 = pd.read_csv(file4)
twitter_may_01 = pd.read_csv(file5)
twitter_may_15 = pd.read_csv(file6)
# Out:
# /Users/jameswhite/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
twitter_mar_01.dtypes
# Out:
# coordinates                    object
# created_at                     object
# hashtags                       object
# media                          object
# urls                           object
# favorite_count                  int64
# id                              int64
# in_reply_to_screen_name        object
# in_reply_to_status_id         float64
# in_reply_to_user_id           float64
# lang                           object
# place                          object
# possibly_sensitive             object
# retweet_count                   int64
# retweet_id                    float64
# retweet_screen_name            object
# source                         object
# text                           object
# tweet_url                      object
# user_created_at                object
# user_screen_name               object
# user_default_profile_image       bool
# user_description               object
# user_favourites_count           int64
# user_followers_count            int64
# user_friends_count              int64
# user_listed_count               int64
# user_location                  object
# user_name                      object
# user_screen_name.1             object
# user_statuses_count             int64
# user_time_zone                float64
# user_urls                      object
# user_verified                    bool
# dtype: object

# %%
twitter_mar_01 = twitter_mar_01[['id', 'created_at', 'place', 'retweet_count']]
twitter_mar_15 = twitter_mar_15[['id', 'created_at', 'place', 'retweet_count']]
twitter_apr_01 = twitter_apr_01[['id', 'created_at', 'place', 'retweet_count']]
twitter_apr_15 = twitter_apr_15[['id', 'created_at', 'place', 'retweet_count']]
twitter_may_01 = twitter_may_01[['id', 'created_at', 'place', 'retweet_count']]
twitter_may_15 = twitter_may_15[['id', 'created_at', 'place', 'retweet_count']]

# %%
twitter_mar = twitter_mar_01.merge(twitter_mar_15, how='outer')
twitter_apr = twitter_apr_01.merge(twitter_apr_15, how='outer')
twitter_may = twitter_may_01.merge(twitter_may_15, how='outer')

# %%
march = twitter_mar[twitter_mar['place'].notna()]

# %%
march
# Out:
#                         id                      created_at  \
# 66     1234090090743451650  Sun Mar 01 12:16:20 +0000 2020
# 232    1234090114340487174  Sun Mar 01 12:16:26 +0000 2020
# 485    1234090142169780225  Sun Mar 01 12:16:32 +0000 2020
# 605    1234090154408673283  Sun Mar 01 12:16:35 +0000 2020
# 641    1234090163418148864  Sun Mar 01 12:16:37 +0000 2020
# ...                    ...                             ...
# 98926  1239171230273548289  Sun Mar 15 12:46:58 +0000 2020
# 99001  1239171238788050944  Sun Mar 15 12:47:00 +0000 2020
# 99028  1239171238515421184  Sun Mar 15 12:47:00 +0000 2020
# 99034  1239171234623037440  Sun Mar 15 12:46:59 +0000 2020
# 99067  1239171238712553472  Sun Mar 15 12:47:00 +0000 2020
#
#                                place  retweet_count
# 66                 Pennsylvania, USA              0
# 232    Rovereto, Trentino-Alto Adige              0
# 485                    Hillsdale, NJ              0
# 605                    Annot, France              0
# 641               Wandsworth, London              0
# ...                              ...            ...
# 98926                San Antonio, TX              0
# 99001             Woking, South East              0
# 99028             Zutphen, Nederland              8
# 99034             Mendoza, Argentina              0
# 99067         British Virgin Islands              0
#
# [711 rows x 4 columns]

# %%
april = twitter_apr[twitter_apr['place'].notna()]

# %%
april
# Out:
#                         id                      created_at  \
# 25     1245322458921676801  Wed Apr 01 12:09:45 +0000 2020
# 46     1245322458149933062  Wed Apr 01 12:09:45 +0000 2020
# 155    1245322470808223745  Wed Apr 01 12:09:48 +0000 2020
# 305    1245322487421755392  Wed Apr 01 12:09:52 +0000 2020
# 362    1245322496162717696  Wed Apr 01 12:09:54 +0000 2020
# ...                    ...                             ...
# 75223  1250407305306238976  Wed Apr 15 12:55:07 +0000 2020
# 75240  1250407312671395841  Wed Apr 15 12:55:09 +0000 2020
# 75558  1250407347094196225  Wed Apr 15 12:55:17 +0000 2020
# 75574  1250407346041286656  Wed Apr 15 12:55:17 +0000 2020
# 75664  1250407351666040832  Wed Apr 15 12:55:18 +0000 2020
#
#                            place  retweet_count
# 25             Crediton, England              0
# 46        West Midlands, England              0
# 155               Tuusula, Suomi              1
# 305               Nairobi, Kenya              0
# 362            Vijayawada, India              0
# ...                          ...            ...
# 75223             Gurgaon, India             24
# 75240  Sumedang Utara, Indonesia              0
# 75558            Kampala, Uganda              1
# 75574             Saravanampatti              1
# 75664             Chillán, Chile              0
#
# [838 rows x 4 columns]

# %%
may = twitter_may[twitter_may['place'].notna()]

# %%
may
# Out:
#                         id                      created_at  \
# 60     1256193425415852032  Fri May 01 12:07:06 +0000 2020
# 140    1256193436442476547  Fri May 01 12:07:08 +0000 2020
# 433    1256193469384712192  Fri May 01 12:07:16 +0000 2020
# 466    1256193465077108737  Fri May 01 12:07:15 +0000 2020
# 764    1256193503115313152  Fri May 01 12:07:24 +0000 2020
# ...                    ...                             ...
# 69315  1261279995495882752  Fri May 15 12:59:19 +0000 2020
# 69341  1261280002764689408  Fri May 15 12:59:20 +0000 2020
# 69361  1261280006728306690  Fri May 15 12:59:21 +0000 2020
# 69483  1261280019558666241  Fri May 15 12:59:24 +0000 2020
# 69656  1261280032208666625  Fri May 15 12:59:27 +0000 2020
#
#                             place  retweet_count
# 60             Kensington, London             10
# 140                  Kantō, Chiba              0
# 433          Lakeland Heights, TX              0
# 466              Banbury, England              0
# 764                 Shimla, India              3
# ...                           ...            ...
# 69315  Egmore Nungambakkam, India              0
# 69341          Navi Mumbai, India              0
# 69361                   Ohio, USA              0
# 69483                   Sri Lanka             21
# 69656                 Houston, TX              0
#
# [729 rows x 4 columns]
