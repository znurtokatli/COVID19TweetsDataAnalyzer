# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
tweets_data_path = 'everything.txt'

# %%
tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue
        
# tweets_data

# %%
tweets = pd.DataFrame(tweets_data)

# %%
# new = tweets.groupby(['created_at'])

# %%
# 
tweets['created_at'] = tweets['created_at'].astype(str)
tweets['created_at'] = [x[:-19] for x in tweets['created_at']]

# %%
tweets['created_at'] = tweets['created_at'].astype(str)

# %%
tweets
# Out:
#         created_at            id               id_str  \
# 0      Sat Feb 06   1.358107e+18  1358107272212344832
# 1      Sat Feb 06   1.358107e+18  1358107272262553600
# 2      Sat Feb 06   1.358107e+18  1358107272375844869
# 3      Sat Feb 06   1.358107e+18  1358107272434438149
# 4      Sat Feb 06   1.358107e+18  1358107272522719239
# ...            ...           ...                  ...
# 25623  Sat Feb 06   1.358110e+18  1358110014456659975
# 25624  Sat Feb 06   1.358110e+18  1358110014578253826
# 25625  Sat Feb 06   1.358110e+18  1358110014309888004
# 25626  Sat Feb 06   1.358110e+18  1358110014578204675
# 25627  Sat Feb 06   1.358110e+18  1358110014737686529
#
#                                                     text  \
# 0      RT @NdsLandesReg: Wie ist die aktuelle Lage in...
# 1                                #alamna @DrTonyLeachon!
# 2      RT @cmclymer: VP Kamala Harris breaks a 50-50 ...
# 3      RT @AJCGlobal: "Somebody has to survive to tel...
# ...
